# %%
import os, sys
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
from scripts.preprocess import cleaning
pre=cleaning()
# Out:
# /Users/amantebeje/Desktop/projects/medical-business-data-scraped-from-telegram-channels

# %%
file='/Users/amantebeje/Desktop/projects/medical-business-data-scraped-from-telegram-channels/telegram_data.csv'
df=pre.load_csv(file)
df
# Out:
# 2025-01-30 19:34:45,320 - INFO - ✅ CSV file '/Users/amantebeje/Desktop/projects/medical-business-data-scraped-from-telegram-channels/telegram_data.csv' loaded successfully.
#                                           Channel Title Channel Username   ID  \
# 0                                      Doctors Ethiopia       @DoctorsET  864
# 1                                      Doctors Ethiopia       @DoctorsET  863
# 2                                      Doctors Ethiopia       @DoctorsET  862
# 3                                      Doctors Ethiopia       @DoctorsET  861
# 4                                      Doctors Ethiopia       @DoctorsET  860
# ...                                                 ...              ...  ...
# 6513  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI    8
# 6514  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI    4
# 6515  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI    3
# ...

# %%
output_file='/Users/amantebeje/Desktop/projects/medical-business-data-scraped-from-telegram-channels/Data/preprocessed/medical_telegram_data.csv'
pre.preprocess(df,output_file)
# Out:
# 2025-01-30 19:35:49,349 - INFO - ✅ Duplicates removed from dataset.
# 2025-01-30 19:35:49,391 - INFO - ✅ Date column formatted to datetime.
# 2025-01-30 19:35:49,394 - INFO - ✅ Missing values filled.
# 2025-01-30 19:35:49,411 - INFO - ✅ Text columns standardized.
# 2025-01-30 19:35:49,443 - INFO - ✅ Emojis extracted and stored in 'emoji_used' column.
# 2025-01-30 19:35:49,508 - INFO - ✅ YouTube links extracted and stored in 'youtube_links' column.
# 2025-01-30 19:35:49,511 - INFO - ✅ Data cleaning completed successfully.
#                                           channel_title channel_username  \
# 0                                      Doctors Ethiopia       @DoctorsET
# 1                                      Doctors Ethiopia       @DoctorsET
# 2                                      Doctors Ethiopia       @DoctorsET
# 3                                      Doctors Ethiopia       @DoctorsET
# 4                                      Doctors Ethiopia       @DoctorsET
# ...
